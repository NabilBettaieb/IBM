# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **NABIL BETTAIEB**
#
# *IT STUDENT AT ESPRIT*

# %% [markdown]
# *I am interested in data science because I would like to predict any thing how will change the world with manipulating  data*

# %% [markdown]
# ### I will print the somme between 3 and 2

# %%
print(3+2)
# Out:
# 5

# %% [markdown]
# In programation we will begin withe an easy exemple we will order this list :
# - 15
# - 19
# - 8
# the result :
# 1. 8
# 2. 15
# 3. 19
# <img src="https://www.ibm.com/brand/experience-guides/developer/b1db1ae501d522a1a4b49613fe07c9f1/01_8-bar-positive.svg" alt="Alt text" title="Title text" />
